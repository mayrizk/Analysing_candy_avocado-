# %%
import pandas as pd #For DataFrames
import numpy as np #Mathmatical Operations
import seaborn as sns #Plotting
import matplotlib.pyplot as plt #Plotting
# %matplotlib inline
plt.style.use('seaborn')

# %%
df=pd.read_csv('avocado.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df.isnull().sum()
# so there is no null values
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
# we could drop unmaed cloumn cause we still will have the index columns
df.drop(columns='Unnamed: 0',inplace=True)
df
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1      2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2      2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3      2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4      2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
# we could also drop xlarge columns
df.drop(columns='XLarge Bags',inplace=True)
df
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1      2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2      2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3      2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4      2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags          type  year  \
# ...

# %%
# lests go on and visualize our dataset  to understand it better

# %%
# at fi4st lets figure out the distrbution of avocato average prices (it is aquantitative variable )
# so we will use histogram
df.plot(kind="hist",y='AveragePrice')
# we could see that the prices follow a normal distrubtion "bell shaped curve"
# the peake of ave prices is around 1.0 :1.3

# %%
# now we need to figure out the distrubtion  prices   mm (quantitive valriable )  vs  type (catogrical varible) 
sns.barplot(x='AveragePrice',y='type' , data=df)
# we could see that organic avocato are more expensive than conventional avocato

# %%
sns.countplot('region',data=df)
plt.xticks(rotation=90)
plt.show()
# toooo many regions so we cant use it as hue/ catogircal varible

# %%
# to make sure again 
df['region'].value_counts()
# Out:
# NewYork                338
# Plains                 338
# Charlotte              338
# GreatLakes             338
# Spokane                338
# Boston                 338
# Columbus               338
# Jacksonville           338
# HartfordSpringfield    338
# Albany                 338
# West                   338
# GrandRapids            338
# NewOrleansMobile       338
# Indianapolis           338
# Louisville             338
# TotalUS                338
# Northeast              338
# Roanoke                338
# BuffaloRochester       338
# MiamiFtLauderdale      338
# StLouis                338
# California             338
# SanFrancisco           338
# SouthCentral           338
# Sacramento             338
# SanDiego               338
# LosAngeles             338
# HarrisburgScranton     338
# Portland               338
# CincinnatiDayton       338
# DallasFtWorth          338
# SouthCarolina          338
# Atlanta                338
# Orlando                338
# ...

# %%
df.plot(kind="scatter",x='region',y='AveragePrice')
plt.xticks(rotation=90)
plt.show()
# the plot showes us that almost every regoin as the same ave prices 
# few points consider as outliers

# %%
#to figure out more info we will use box plot 
sns.boxplot(x='AveragePrice',y='type' , data=df)
# we could see that the medien price price for conventional avocato is around 1.2 ave price 
# Q1 the 25 % of our points are around 1.0:1.2
#Q3 the 75% of our points are around 1.2: 1.45 
# one outliers before .5 
# so many outliers after 1.7 for ave price
##################################
# for the organig avocato
# the mediem ave price is around 1.65 
# Q1 the 25 % of our points are around 1.48:1.65 ave price
#Q3 the 75% of our points are around 1.65: 1.8 
# many outliers befor .75 
#  and much more outliers after 2.55 for ave price
##################################

# %%
def plott(x,y,df):
    plt.title (x + " vs "+ y)
    sns.countplot(x=x,hue=y,data=df)

# %%
plt.figure(figsize=(20,20))
plt.subplot(1,3,1)
plott('4046','type',df)
plt.subplot(1,3,2)
plott('4225','type',df)
plt.subplot(1,3,3)
plott('4770','type',df)
### to many values and it doesnot make that sense so we could agnor them (4046 , 4225,4770)

# %%
def hplot(x):
    df.plot(kind="box",y=x)

# %%
# to analysi years of the servie 
sns.countplot('year',data=df)
# we could see that most of the servie happend in 2017 and least of them happend in 2018
# 2015 and 2016 are equll

# %%
df.plot(kind="hist",y='Total Volume')
# we could see that most of vslues are in range of 0:1.3 totla volume
# so little point in range of .5:1 and range of 2.5:4.4 totsl volume

# %%
df.plot(kind="hist",y='Total Bags')
# we could see that most of values are in range of 0 : .2 total bages
# so little points in range of .27:1.75
# no points at all in range of 1.75 :2.00

# %%
df.plot(kind="hist",y='Small Bags')
# we could see that most of values are in range of 0 : .29 total bages
# so little points in range of .4 :.9

# %%
df.plot(kind="hist",y='Large Bags')
# we could see that most of values are in range of 0 : .29 total bages
# so little points in range of .4 :.9

# %%
df.plot(kind="box",y='Large Bags')
#large bages seemes to have so many outliers

# %% [markdown]
# # Done
